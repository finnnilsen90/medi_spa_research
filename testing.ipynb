# %%
from MediSpaAssumptions import MediAssumptions

MediSpaAssumptions = MediAssumptions(operating_hours_per_day=7, days_open_per_month=12).utilization()
print(MediSpaAssumptions["utilization_pct"])
# Out:
# 72.92%
